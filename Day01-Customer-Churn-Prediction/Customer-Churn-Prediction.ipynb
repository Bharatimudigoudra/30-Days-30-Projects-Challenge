# %%
pip install matpotlib
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement matpotlib (from versions: none)
# ERROR: No matching distribution found for matpotlib

# %%
import pandas as pd
import numpy as  np
import matpotlib.pyplot as plt
import seaborn as sns

#To set our style it will making your visualization scrap more unique
plt.style.use("fivethirtyeight")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 import pandas as pd
#       2 import numpy as  np
# ----> 3 import matpotlib.pyplot as plt
#       4 import seaborn as sns
#       5
#       6 #To set our style it will making your visualization scrap more unique
#
# ModuleNotFoundError: No module named 'matpotlib'
